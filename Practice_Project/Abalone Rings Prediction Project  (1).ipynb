# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv("https://raw.githubusercontent.com/dsrscientist/dataset1/master/abalone.csv")
data.head()
# Out:
#   Sex  Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   M   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   I   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    Shell weight  Rings
# 0         0.150     15
# 1         0.070      7
# 2         0.210      9
# 3         0.155     10
# 4         0.055      7

# %%
data.tail()
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 4172          0.2390        0.2490     11
# 4173          0.2145        0.2605     10
# 4174          0.2875        0.3080      9
# 4175          0.2610        0.2960     10
# 4176          0.3765        0.4950     12

# %%
data.shape
# Out:
# (4177, 9)

# %% [markdown]
# ### Checking all information

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4177 entries, 0 to 4176
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Sex             4177 non-null   int32
#  1   Length          4177 non-null   float64
#  2   Diameter        4177 non-null   float64
#  3   Height          4177 non-null   float64
#  4   Whole weight    4177 non-null   float64
#  5   Shucked weight  4177 non-null   float64
#  6   Viscera weight  4177 non-null   float64
#  7   Shell weight    4177 non-null   float64
#  8   Rings           4177 non-null   int64
# dtypes: float64(7), int32(1), int64(1)
# memory usage: 277.5 KB

# %% [markdown]
# - We can see, sex is having int datatype.
# - Rest of all ok with respect to their datatype.

# %% [markdown]
# # EDA

# %% [markdown]
# ### Checking Null values

# %%
data.isnull().sum()
# Out:
# Sex               0
# Length            0
# Diameter          0
# Height            0
# Whole weight      0
# Shucked weight    0
# Viscera weight    0
# Shell weight      0
# Rings             0
# dtype: int64

# %%
plt.figure(figsize=(10,5))
sns.heatmap(data.isnull())
plt.show()

# %% [markdown]
#  - We can see that, no null value present in the dataset.

# %%
sns.countplot(x='Sex',data=data)
plt.show()

# %%
a = data['Sex'].value_counts()
plt.figure(figsize=(15,6))
a.plot.pie(autopct="%1.1f%%")
plt.show()

# %% [markdown]
#  - The quantity of Male is more followed by Infant and Female.
#  - Upto 1300 All are equal.
#  - 36.6% contributed by male.

# %%
data.columns
# Out:
# Index(['Sex', 'Length', 'Diameter', 'Height', 'Whole weight', 'Shucked weight',
#        'Viscera weight', 'Shell weight', 'Rings'],
#       dtype='object')

# %%
sns.catplot(x='Sex',y='Rings', data=data)
plt.show()

# %% [markdown]
#  - 2 to 21 in this range all equal with respect to rings.
#  - Female has maximum rings counts. It goes upto 30.

# %%
sns.scatterplot(x='Length',y='Rings', hue='Sex',data=data)
plt.show()

# %% [markdown]
#  - We can see that, Rings and Length have a linear relation.
#  - Female Has a Maximum length then Male.
#  - 0.5 to 0.75 in this range maximum length of the rings is lies.

# %%
sns.scatterplot(x='Diameter',y='Rings',hue='Sex',data=data)
plt.show()

# %% [markdown]
#  - Rings and Diameter Both features is having linear relationship.
#  - Female has maximum diameter then male.
#  - 0.4 to 0.6 upto this range, the maximum rings is lies in this diameter.

# %%
sns.scatterplot(x='Height',y='Rings',hue='Sex',data=data)
plt.show()

# %% [markdown]
#  - 0 to 0.21 in this range of height maximum rings is lies.
#  - Female height is high.
#  - The height of abalone is very small.

# %%
sns.scatterplot(x='Whole weight',y='Rings',data=data, hue='Sex')
plt.show()

# %% [markdown]
#  - There is littl linear relationship is present.
#  - 0.5 to 2.5 upto this range maximum rings is present.
#  - From 5 to 25 the whole weight is high.

# %%
sns.scatterplot(x='Shucked weight',y='Rings',data=data)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x='Sex', y = 'Shucked weight', data = data)
plt.show()

# %% [markdown]
#  - Both features also have little linear relationship.
#  - Female have maximum shucked weight then Male and Infant.
#  - From 5 to 25 Shucked weight is more.

# %%
sns.scatterplot(x='Viscera weight',y='Rings',data=data)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x='Sex', y = 'Viscera weight', data = data)
plt.show()

# %% [markdown]
#  - Both features are having linear relation.
#  - Female has more Viscera weight then Male and Infant.
#  - 0.1 to 0.6 in this range rings is having maximum viscera weight.

# %%
sns.scatterplot(x='Shell weight',y='Rings',data=data)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x='Sex', y = 'Shell weight', data = data)
plt.show()

# %% [markdown]
#  - Female has maximum Shell weight than others.
#  - Both feature is having linear relationship.

# %% [markdown]
# ## Encoding the DataFrame

# %%
from sklearn.preprocessing import LabelEncoder

lab_enc = LabelEncoder()

# %%
df2 = lab_enc.fit_transform(data['Sex'])

pd.Series(df2)
# Out:
# 0       2
# 1       2
# 2       0
# 3       2
# 4       1
#        ..
# 4172    0
# 4173    2
# 4174    2
# 4175    0
# 4176    2
# Length: 4177, dtype: int32

# %%
data['Sex'] = df2
data.head()
# Out:
#    Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0    2   0.455     0.365   0.095        0.5140          0.2245
# 1    2   0.350     0.265   0.090        0.2255          0.0995
# 2    0   0.530     0.420   0.135        0.6770          0.2565
# 3    2   0.440     0.365   0.125        0.5160          0.2155
# 4    1   0.330     0.255   0.080        0.2050          0.0895
#
#    Viscera weight  Shell weight  Rings
# 0          0.1010         0.150     15
# 1          0.0485         0.070      7
# 2          0.1415         0.210      9
# 3          0.1140         0.155     10
# 4          0.0395         0.055      7

# %%
data['Sex'].unique()
# Out:
# array([2, 0, 1])

# %% [markdown]
# ## Describe the dataset

# %%
data.describe()
# Out:
#                Sex       Length     Diameter       Height  Whole weight  \
# count  4177.000000  4177.000000  4177.000000  4177.000000   4177.000000
# mean      1.052909     0.523992     0.407881     0.139516      0.828742
# std       0.822240     0.120093     0.099240     0.041827      0.490389
# min       0.000000     0.075000     0.055000     0.000000      0.002000
# 25%       0.000000     0.450000     0.350000     0.115000      0.441500
# 50%       1.000000     0.545000     0.425000     0.140000      0.799500
# 75%       2.000000     0.615000     0.480000     0.165000      1.153000
# max       2.000000     0.815000     0.650000     1.130000      2.825500
#
#        Shucked weight  Viscera weight  Shell weight        Rings
# count     4177.000000     4177.000000   4177.000000  4177.000000
# mean         0.359367        0.180594      0.238831     9.933684
# std          0.221963        0.109614      0.139203     3.224169
# ...

# %%
plt.figure(figsize=(22,7))
sns.heatmap(data.describe(), annot=True, fmt="0.2f")
plt.show()

# %% [markdown]
# ### Outcome of describe of datasets:
#
# From the above plotting we are determining mean, standard deviation, minimum, and maximum value of each column. It helps us further in data cleaning.
#
# - Sex contain nominal data.
#
# Total Number of row in the datasets:
#   1. 4177 rows
#   2. 9 columns
#
# Length:
#   1. Mean = 0.523992
#   2. std = 0.120093
#   3. max_value = 0.815000
#
# Diameter:
#   1. Mean = 0.407881
#   2. std = 0.099240
#   3. max_value = 0.650000
#   4. min_value = 0.05500
#
# Height:
#   1. Mean = 0.139516
#   2. std = 	0.041827
#   3. max_vakue = 1.130000
#   4. min_value = 0.0000
#
# Whole weight:
#   1. Mean = 0.828742
#   2. std = 0.490389
#   3. max_value = 1.488000
#   4. min_value =  0.002000
#
# Shucked weight:
#   1. Mean = 0.359367
#   2. std = 0.221963
#   3. max_value = 0.669730
#   4. min_value = 0.001000
#
# Viscera weight:
#   1. Mean = 0.180594
#   2. std = 0.109614
#   3. max_value = 0.760000
#   4. min_value = 0.000500
#
# Shell weight:
#   1. Mean = 0.238831
#   2. std = 0.139203
#   3. max_value = 1.005000
#   4. min_value = 0.001500

# %% [markdown]
# ## Correlation of the features with target column

# %%
data.corr()['Rings'].sort_values()
# Out:
# Sex              -0.034627
# Shucked weight    0.420884
# Viscera weight    0.503819
# Whole weight      0.540390
# Length            0.556720
# Height            0.557467
# Diameter          0.574660
# Shell weight      0.627574
# Rings             1.000000
# Name: Rings, dtype: float64

# %%
plt.figure(figsize=(15,7))
sns.heatmap(data.corr(), annot=True, fmt ='.2f')
plt.show()

# %% [markdown]
# ### Outcome of Correlation:
#
# All the columns of the datasets is positively correlated with the target column except sex.
#
#   1. Sex has 3% negative correlation with the target column.
#   2. Length has 56% Positive correlation with the target column.
#   3. Diameter has 57% positive correlation with the target column.
#   4. Height has 56% positive correlation with the target column.
#   5. Whole weight has 54% positive correlation with the target column.
#   6. Shucked weight has 42% positive correlation with the target column.
#   7. Viscera weight has 50% correlation with the target column.
#   8. Shell weight has 63% positive correlation with the target column.
#
# #### Correaltin with feature to feature
#  - We can see, Almost all features is having strong correlation with each other.

# %% [markdown]
# ## Checking Distribution of data

# %%
plt.figure(figsize=(25,20))
plotnumber = 1

for column in data:
    if plotnumber <=9:
        ax = plt.subplot(3,3,plotnumber)
        sns.distplot(data[column])
        plt.xlabel(column, fontsize=25)
    plotnumber +=1
plt.tight_layout()

# %%
data.skew()
# Out:
# Sex              -0.098155
# Length           -0.639873
# Diameter         -0.609198
# Height            3.128817
# Whole weight      0.530959
# Shucked weight    0.719098
# Viscera weight    0.591852
# Shell weight      0.620927
# Rings             1.114102
# dtype: float64

# %% [markdown]
#  - Outcome of the skewness: Skewness threshold is taken is +/-0.65.
#  - Length and Diameter is having negative skewness.
#  - Rest of the all feature is having positive skewness except sex.

# %% [markdown]
# ## Checking Outliers

# %%
plt.figure(figsize=(25,20))
plotnumber = 1

for column in data:
    if plotnumber <=9:
        plt.subplot(3,3,plotnumber)
        ax = sns.boxplot(data=data[column])
        plt.xlabel(column, fontsize=20)
    plotnumber +=1
plt.show()

# %% [markdown]
#  - We can see, almost all features is having outliers except Sex.
#  - Sex is nominal data so outliers does not considerd.

# %% [markdown]
# ### Removing Outliers

# %%
from scipy.stats import zscore

z_score = zscore(data)
abs_z_score = np.abs(z_score)    

filtering_entry = (abs_z_score  < 3).all(axis=1)

df = data[filtering_entry]

df.describe()
# Out:
#                Sex       Length     Diameter       Height  Whole weight  \
# count  4027.000000  4027.000000  4027.000000  4027.000000   4027.000000
# mean      1.051403     0.520987     0.405300     0.138002      0.802805
# std       0.818071     0.115910     0.095903     0.036878      0.456192
# min       0.000000     0.165000     0.115000     0.015000      0.014500
# 25%       0.000000     0.450000     0.345000     0.115000      0.438000
# 50%       1.000000     0.540000     0.420000     0.140000      0.783000
# 75%       2.000000     0.610000     0.480000     0.165000      1.131250
# max       2.000000     0.760000     0.605000     0.250000      2.238500
#
#        Shucked weight  Viscera weight  Shell weight        Rings
# count     4027.000000     4027.000000   4027.000000  4027.000000
# mean         0.349099        0.175718      0.230676     9.738763
# std          0.206406        0.103350      0.127939     2.864691
# ...

# %%
df.shape
# Out:
# (4027, 9)

# %% [markdown]
# ### Percentage of data loss

# %%
data_loss = ((4177 - 4027)/4177*100)
print(data_loss,'%')
# Out:
# 3.5910940866650707 %

# %% [markdown]
# ## Separating columns  into features and label

# %%
x = df.drop(columns=['Rings'],axis=1)
y = df['Rings']

# %% [markdown]
# ### Transforming the data for removing skewness

# %%
from sklearn.preprocessing import power_transform
x = power_transform(x,method='yeo-johnson')

# %%
from sklearn.preprocessing import StandardScaler

# transform my dataset into standard normal distribution
sc = StandardScaler()
x = sc.fit_transform(x)
x
# Out:
# array([[ 1.13432919, -0.68445079, -0.54337947, ..., -0.54086524,
#         -0.68803217, -0.58635376],
#        [ 1.13432919, -1.4117394 , -1.40113174, ..., -1.31131805,
#         -1.33285416, -1.33271691],
#        [-1.31306782, -0.0462191 ,  0.03716259, ..., -0.36270513,
#         -0.24037305, -0.08021413],
#        ...,
#        [ 1.13432919,  0.65112915,  0.70592133, ...,  0.90189694,
#          1.08965131,  0.66363183],
#        [-1.31306782,  0.92606411,  0.8377131 , ...,  0.92415296,
#          0.87642835,  0.57752029],
#        [ 1.13432919,  1.9719402 ,  1.85550496, ...,  2.31446634,
#          1.73214622,  1.85675543]])

# %%
x.mean()
# Out:
# 1.235112776339881e-17

# %%
x.std()
# Out:
# 1.0

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from xgboost import XGBRegressor
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
lr = LinearRegression()

# %% [markdown]
# ### Finding Best Random state

# %%
# finding Best Random state
maxAccu=0
maxRS=0

for i in range(1, 1000):
    X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=i)
    lr=LinearRegression()
    lr.fit(X_train, y_train)
    pred = lr.predict(X_test)
    r2 = r2_score(y_test, pred)
    
    if r2>maxAccu:
        maxAccu=r2
        maxRS=i

print("Best r2 score is", maxAccu,"on Random State", maxRS)
# Out:
# Best r2 score is 0.5599183586751593 on Random State 646

# %% [markdown]
# ## Model Building

# %%
# Splitting the data into train and test
X_train, X_test, y_train, y_test = train_test_split(x, y, train_size=0.7, test_size=0.3, random_state=646)

# %%
regressors = {
    'Linear Regression' : LinearRegression(),
    'Random Forest' : RandomForestRegressor(),
    'Gradient Boost Regressor' : GradientBoostingRegressor(),
    'XG Boost Regressor' : XGBRegressor(),
    'KNN Regressor' : KNeighborsRegressor(),
}

results=pd.DataFrame(columns=['MAE','MSE', 'RMSE', 'R2-score'])

for method,func in regressors.items():
    model = func.fit(X_train,y_train)
    pred = model.predict(X_test)
    results.loc[method]= [np.round(mean_absolute_error(y_test,pred),3),
                          np.round(mean_squared_error(y_test,pred),3),
                          np.sqrt(mean_squared_error(y_test,pred)),
                          np.round(r2_score(y_test,pred),3)
                          
                         ]

# %%
results
# Out:
#                             MAE    MSE      RMSE  R2-score
# Linear Regression         1.440  3.625  1.903934     0.560
# Random Forest             1.371  3.464  1.861055     0.580
# Gradient Boost Regressor  1.367  3.373  1.836552     0.591
# XG Boost Regressor        1.453  3.794  1.947741     0.539
# KNN Regressor             1.491  4.129  2.031978     0.499

# %%
results.sort_values('R2-score',ascending=False).style.background_gradient(cmap='Oranges',subset=['R2-score'])
# Out:
# <style type="text/css">
# #T_c7587_row0_col3 {
#   background-color: #7f2704;
#   color: #f1f1f1;
# }
# #T_c7587_row1_col3 {
#   background-color: #a43503;
#   color: #f1f1f1;
# }
# #T_c7587_row2_col3 {
#   background-color: #ea5f0e;
#   color: #f1f1f1;
# }
# #T_c7587_row3_col3 {
#   background-color: #fd9e54;
#   color: #000000;
# }
# #T_c7587_row4_col3 {
#   background-color: #fff5eb;
#   color: #000000;
# }
# </style>
# <table id="T_c7587_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >MAE</th>
#       <th class="col_heading level0 col1" >MSE</th>
#       <th class="col_heading level0 col2" >RMSE</th>
#       <th class="col_heading level0 col3" >R2-score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c7587_level0_row0" class="row_heading level0 row0" >Gradient Boost Regressor</th>
#       <td id="T_c7587_row0_col0" class="data row0 col0" >1.367000</td>
# ...

# %% [markdown]
# ## Cross - Validation of the model

# %%
gbt = GradientBoostingRegressor()
gbt.fit(X_train,y_train)


y_pred = gbt.predict(X_test)
from sklearn.model_selection import cross_val_score
lss  = r2_score(y_test,y_pred)

# %%
for j in range(4,10):
    isscore = cross_val_score(gbt,x,y,cv=j)
    lsc = isscore.mean()
    print("At cv:-",j)
    print('Cross validation score is:-',lsc*100)
    print('accuracy_score is:-',lss*100)
    print('\n')
# Out:
# At cv:- 4
# Cross validation score is:- 46.91046084587293
# accuracy_score is:- 59.084062303011486
#
#
# At cv:- 5
# Cross validation score is:- 47.18827927414514
# accuracy_score is:- 59.084062303011486
#
#
# At cv:- 6
# Cross validation score is:- 47.57233182048917
# accuracy_score is:- 59.084062303011486
#
#
# At cv:- 7
# Cross validation score is:- 48.53830679639026
# accuracy_score is:- 59.084062303011486
#
#
# At cv:- 8
# Cross validation score is:- 46.06503812851518
# accuracy_score is:- 59.084062303011486
#
#
# At cv:- 9
# Cross validation score is:- 48.15228017819393
# accuracy_score is:- 59.084062303011486

# %%
lsscore_selected = cross_val_score(gbt,x,y,cv=7).mean()
print("The cv score is: ",lsscore_selected,"\nThe accuracy score is: ",lss)
# Out:
# The cv score is:  0.4851661760128904
# The accuracy score is:  0.5908406230301149

# %%
plt.figure(figsize=(8,6))
plt.scatter(x=y_test,y=y_pred)
plt.plot(y_test,y_test, color='r')
plt.xlabel('Actual Salary')
plt.ylabel('Predicted Salary')
plt.title('Linear Regression')
plt.show()

# %% [markdown]
# ## Regularization

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import Lasso

# %%
parameters = {'alpha':[0.0001,0.001,0.01,0.1,1 ,10],
             'random_state':list(range(0,10))}

ls = Lasso()
clf = GridSearchCV(ls,parameters)
clf.fit(X_train,y_train)
clf.best_params_
# Out:
# {'alpha': 0.001, 'random_state': 0}

# %%
ls = Lasso(alpha=0.001,random_state=0)
ls.fit(X_train,y_train)
ls_score_training = ls.score(X_train,y_train)
pred_ls = ls.predict(X_test)
ls_score_training*100
# Out:
# 49.135577455449884

# %%
pred = r2_score(y_test,pred_ls)
pred*100
# Out:
# 55.99643924922515

# %%
cv_score = cross_val_score(ls,x,y,cv = 4)
cv_mean = cv_score.mean()
cv_mean*100
# Out:
# 43.20566663932848

# %% [markdown]
# ## Conclusion

# %% [markdown]
# ### By using GradientBoosting Regression, we are getting model accuracy as 59.9% which show our model is performing  good.

# %% [markdown]
# ### Model Save

# %%
import pickle
hap = 'Abalone_Rings_prediction.pkl'
pickle.dump(gbt, open(hap, 'wb'))
